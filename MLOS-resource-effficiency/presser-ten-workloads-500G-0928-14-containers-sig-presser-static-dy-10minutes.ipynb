# %%
import pandas as pd
import os
import random
import threading
import time
import datetime
import csv
import matplotlib.pyplot as plt
import numpy as np



# work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-28-19-59/'

# work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-29-11-30/'


# work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-29-14-45/'

#workd_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-29-15-36/'

#work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-08-51/'

work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-11-05/'


#work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-11-05-bak/'

# work_dir='/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-12-41/'
def get_time_second(str):
    try:
        time_in_second = time.mktime(time.strptime(str, '%Y-%m-%d %H:%M:%S'))
        return time_in_second
    except Exception as e:
        print(e)

def empty_string(item):
    return len(str(item).strip()) == 0

def aggregate_cpu_resources(workload):
    filenames = os.listdir(work_dir)

    csv_slave1 = []
    csv_slave2 = []
    csv_slave3 = []
    csv_slave4 = []
    csv_slave5 = []
    csv_slave6 = []
    csv_slave7 = []
    csv_slave8 = []
    csv_slave9 = []
    csv_slave10 = []
    csv_slave11 = []
    csv_slave12 = []
    csv_slave13 = []
    csv_slave14 = []

    cnt = 0
    cpu_capacity = 50*100
    left_cpu_capacity = cpu_capacity
    for filename in filenames:
        file_path = os.path.join(work_dir, filename)
       # print('文件名：%s' % filename)
        
        if workload in filename and 'hadoop-slave1.1.csv' in filename:
            print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave1.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave2' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave2.append(row)
                cnt=cnt+1
        
        if workload in filename and 'hadoop-slave3' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave3.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave4' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave4.append(row)
                cnt=cnt+1
         
    
        if workload in filename and 'hadoop-slave5' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave5.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave6' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave6.append(row)
                cnt=cnt+1
        
        if workload in filename and 'hadoop-slave7' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave7.append(row)
                cnt=cnt+1
        
        if workload in filename and 'hadoop-slave8' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave8.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave9' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave9.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave10' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave10.append(row)
                cnt=cnt+1
        
        if workload in filename and 'hadoop-slave11' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave11.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave12' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave12.append(row)
                cnt=cnt+1
                
        if workload in filename and 'hadoop-slave13' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave13.append(row)
                cnt=cnt+1
        
        if workload in filename and 'hadoop-slave14' in filename:
#             print('文件完整路径：%s\n' % file_path)
            with open(file_path) as f:
                temp = csv.reader(f)
                for row in temp:
                    csv_slave14.append(row)
                cnt=cnt+1
        
    if cnt < 13:
        return
    return [[],csv_slave1,csv_slave2,csv_slave3,csv_slave4,csv_slave5,csv_slave6,csv_slave7,
            csv_slave8,csv_slave9,csv_slave10,csv_slave11, csv_slave12,csv_slave13,csv_slave14]

csv_data=aggregate_cpu_resources("hadoop")

headers = ['time', 'container_id', 'container_name', 'CPU', 'mem_usage','','mem_capacity','mem%','NET input','','NEToutput','Block input','','Block output','PIDS']
# csv_slave1 = pd.DataFrame(csv_slave1,columns=headers)
# csv_slave1.rename(columns=csv_slave1.iloc[0], inplace = True)
# csv_slave1.drop([0], inplace = True)

slaves = [[]]
for i in range(1,15):
    temp_pd = pd.DataFrame(csv_data[i],columns=headers)
    
    temp_pd.drop([0], inplace = True)
    if len(temp_pd) ==0 :
        print(i)
    temp_pd['time'] = pd.to_datetime(temp_pd['time'])
    slaves.append(temp_pd)
    
# slaves[14]
    

max_start_time=0
for i in range(1,15):
    if i==1:
        max_start_time = slaves[1].iloc[0]['time']
    else:
        max_start_time = max(max_start_time, slaves[i].iloc[0]['time'])

# max_start_time = max(max_start_time, max(slaves[8].iloc[0]['time'],   slaves[9].iloc[0]['time']))
for i in range(1,15):
    slaves[i].drop(slaves[i][slaves[i].time < max_start_time].index, inplace=True)


# df_result = pd.DataFrame(columns=['slave1CPU', 'slave2CPU', 'slave3CPU','slave4CPU',
#                                   'slave5CPU','slave6CPU','sum_CPU'])

df_result = pd.DataFrame()

df_result['slave1time']=slaves[1]['time']
df_result['slave1CPU']=slaves[1]['CPU'].str.strip('%').astype(float)
df_result['slave1Mem']=slaves[1]['mem_usage'].astype(float)

df_result['slave2time']=slaves[2]['time']
df_result['slave2CPU']=slaves[2]['CPU'].str.strip('%').astype(float)
df_result['slave2Mem']=slaves[2]['mem_usage'].astype(float)


df_result['slave3time']=slaves[3]['time']
df_result['slave3CPU']=slaves[3]['CPU'].str.strip('%').astype(float)
df_result['slave3Mem']=slaves[3]['mem_usage'].astype(float)


df_result['slave4time']=slaves[4]['time']
df_result['slave4CPU']=slaves[4]['CPU'].str.strip('%').astype(float)
df_result['slave4Mem']=slaves[4]['mem_usage'].astype(float)


df_result['slave5time']=slaves[5]['time']
df_result['slave5CPU']=slaves[5]['CPU'].str.strip('%').astype(float)
df_result['slave5Mem']=slaves[5]['mem_usage'].astype(float)


df_result['slave6time']=slaves[6]['time']
df_result['slave6CPU']=slaves[6]['CPU'].str.strip('%').astype(float)
df_result['slave6Mem']=slaves[6]['mem_usage'].astype(float)

df_result['slave7time']=slaves[7]['time']
df_result['slave7CPU']=slaves[7]['CPU'].str.strip('%').astype(float)
df_result['slave7Mem']=slaves[7]['mem_usage'].astype(float)

df_result['slave8time']=slaves[8]['time']
df_result['slave8CPU']=slaves[8]['CPU'].str.strip('%').astype(float)
df_result['slave8Mem']=slaves[8]['mem_usage'].astype(float)

df_result['slave9time']=slaves[9]['time']
df_result['slave9CPU']=slaves[9]['CPU'].str.strip('%').astype(float)
df_result['slave9Mem']=slaves[9]['mem_usage'].astype(float)

df_result['slave10time']=slaves[10]['time']
df_result['slave10CPU']=slaves[10]['CPU'].str.strip('%').astype(float)
df_result['slave10Mem']=slaves[10]['mem_usage'].astype(float)

df_result['slave11time']=slaves[11]['time']
df_result['slave11CPU']=slaves[11]['CPU'].str.strip('%').astype(float)
df_result['slave11Mem']=slaves[11]['mem_usage'].astype(float)

df_result['slave12time']=slaves[12]['time']
df_result['slave12CPU']=slaves[12]['CPU'].str.strip('%').astype(float)
df_result['slave12Mem']=slaves[12]['mem_usage'].astype(float)

df_result['slave13time']=slaves[13]['time']
df_result['slave13CPU']=slaves[13]['CPU'].str.strip('%').astype(float)
df_result['slave13Mem']=slaves[13]['mem_usage'].astype(float)

df_result['slave14time']=slaves[14]['time']
df_result['slave14CPU']=slaves[14]['CPU'].str.strip('%').astype(float)
df_result['slave14Mem']=slaves[14]['mem_usage'].astype(float)

for i in range(1,15):
    index_cpu = "slave"+str(i)+"CPU"
    index_mem = "slave"+str(i)+"Mem"
    if i == 1:
        df_result['sum_CPU'] = df_result['slave1CPU']
        df_result['sum_Mem'] = df_result['slave1Mem'] 
    else:
        df_result['sum_CPU'] =  df_result['sum_CPU'] + df_result[str(index_cpu)]
        df_result['sum_Mem'] =  df_result['sum_Mem']  + df_result[str(index_mem)]

# df_result['sum_CPU'] = df_result['slave1CPU'] + \
#                      df_result['slave2CPU'] + df_result['slave3CPU'] + \
#                      df_result['slave4CPU'] + df_result['slave5CPU'] + df_result['slave6CPU'] + \
#                      df_result['slave7CPU'] + df_result['slave8CPU'] + df_result['slave9CPU']

# df_result['sum_Mem'] = df_result['slave1Mem'] + \
#                      df_result['slave2Mem'] + df_result['slave3Mem'] + \
#                      df_result['slave4Mem'] + df_result['slave5Mem'] + df_result['slave6Mem'] + \
#                      df_result['slave7Mem'] + df_result['slave8Mem'] + df_result['slave9Mem']



# ts = pd.Series(df_result['slave1CPU'], index=df_result['slave1time'])
# ts = ts.cumsum()
# ts.plot();

# df_result.plot(x="slave1time", y=["slave1CPU", "slave2CPU", 
#                                   "slave7CPU","slave8CPU","sum_CPU"])

# plt.figure(figsize=(5,2))

import matplotlib.pyplot as plt
import numpy as np



from importlib import reload

reload(plt)
from matplotlib import rcParams

config = {
    "font.family": 'Times New Roman', # 衬线字体
    "font.size": 10, # 相当于小四大小
    "font.serif": ['Times New Roman'], # 宋体
    "mathtext.fontset": 'stix', # matplotlib渲染数学字体时使用的字体，和Times New Roman差别不大
    'axes.unicode_minus': False # 处理负号，即-号
}
rcParams.update(config)

plt.figure(dpi=200)


df_result.plot(x="slave1time", y=["slave7CPU","slave8CPU","slave9CPU","sum_CPU"])

# df_result.plot(x="slave1time", y=["slave1CPU","slave10CPU","slave13CPU","sum_CPU"])


# df_result.plot(x="slave1time", y=["slave1CPU", "slave2CPU", "slave3CPU","slave4CPU",
#                                   "slave5CPU","slave6CPU","slave7CPU","slave8CPU","sum_CPU"])

fig = plt.gcf()
fig.set_size_inches(16, 8)

plt.show()
# Out:
# 文件完整路径：/home/lemaker/open-source/Lab/Pressor/papers_data/sigmod/sigmod-presser-static-dy-6containers-500G/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-11-05/sigmod-presser-static-dy-6containers-500G-time-2022-09-30-11-05-hadoop-slave1.1.csv

# %%
# press_five_tpcds_500G_result= pd.read_pickle("./five_adjust_cpu_14containers_presser-static-500G.pkl")  
# press_five_tpcds_500G_result['sum_CPU'] = press_five_tpcds_500G_result['sum_CPU'] / 100
df_result['sum_CPU'] = df_result['sum_CPU'] /100
# df_result.to_pickle("./presser-ten-workloads-500G-0928-14-containers-sig-dac.pkl")
# press_five_tpcds_500G_result.drop(press_five_tpcds_500G_result.loc[press_five_tpcds_500G_result.index>400].index, inplace=True)

# %%
dac_500G_pickle= pd.read_pickle("./presser-ten-workloads-500G-0928-14-containers-sig-dac.pkl")  
# dac_500G_pickle['sum_CPU'] = dac_500G_pickle['sum_CPU'] / 100

# %%
df_result.drop(df_result.loc[df_result.index >500].index, inplace=True)

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"

# %%
import matplotlib.pyplot as plt
import numpy as np



from importlib import reload

reload(plt)
from matplotlib import rcParams

config = {
    "font.family": 'Times New Roman', # 衬线字体
    "font.size": 10, # 相当于小四大小
    "font.serif": ['Times New Roman'], # 宋体
    "mathtext.fontset": 'stix', # matplotlib渲染数学字体时使用的字体，和Times New Roman差别不大
    'axes.unicode_minus': False # 处理负号，即-号
}
rcParams.update(config)

plt.figure(dpi=200)


# plt.plot(df_result['slave1time'],df_result['nor_sum_cpu_allocated'])


plt.plot(df_result.index,df_result['sum_CPU'],label="PRESSER",color='tab:red')

plt.plot(dac_500G_pickle.index,dac_500G_pickle['sum_CPU'],label="DAC",color='tab:blue')

# plt.plot(np.,df_result['nor_sum_cpu_allocated'])

# plt.plot(np.arange(0, 300,1, dtype=int),df_result['nor_sum_cpu_allocated'])

# plt.ylim(0,1)

# plt.yticks(np.arange(0, 1.2, step=0.5))
# legend
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 6}

#plt.legend(loc="upper right",prop=plt.rc('font', **font))
plt.legend(loc="upper right",prop=plt.rc('font', **font), bbox_to_anchor=(0.85,1), labelspacing=0.1,
#            shadow=True,
#           fancybox=True,
#           facecolor='#C19A6B',
           framealpha=1,
          edgecolor='black')

plt.xlim(0,500)
plt.yticks(np.arange(0, 400, step=100))


plt.grid(axis='y',color='black', linestyle='--', linewidth=1)



# plt.title("TPCds-500GB - six SQLs")
plt.xlabel("Time taken (seconds)",fontweight='bold',fontsize=9)
plt.ylabel("CPU Cores",fontweight='bold',fontsize=9)

# plt.tight_layout()

plt.tight_layout(pad=0)

# figure size
fig = plt.gcf()
fig.set_size_inches(7, 1)



# plt.figure(figsize=(6, 1))
plt.savefig('./TPCds-500GB-cpu-runtime.pdf', format='pdf', bbox_inches='tight')


plt.show()

# %%
print(df_result['sum_CPU'].mean() / 288, df_result['sum_Mem'].mean() / 600)
# Out:
# 0.46808650069026103 0.6055536724163321

# %%
df_result['sum_CPU'].describe()
# Out:
# count    498.000000
# mean     134.808912
# std       78.338007
# min        0.080000
# 25%       84.835150
# 50%      114.759650
# 75%      175.161450
# max      323.323100
# Name: sum_CPU, dtype: float64

# %%
df_result['sum_Mem'].describe()
# Out:
# count    498.000000
# mean     363.332203
# std      122.567016
# min      174.271820
# 25%      246.587445
# 50%      348.306820
# 75%      490.396733
# max      547.831653
# Name: sum_Mem, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors

reload(plt)
# plt.figure(figsize=(6,1))

from matplotlib import rcParams

config = {
    "font.family": 'Times New Roman', # 衬线字体
    "font.size": 10, # 相当于小四大小
    "font.serif": ['Times New Roman'], # 宋体
    "mathtext.fontset": 'stix', # matplotlib渲染数学字体时使用的字体，和Times New Roman差别不大
    'axes.unicode_minus': False # 处理负号，即-号
}
rcParams.update(config)

plt.figure(dpi=200)

# plt.plot(df_result['slave1time'],df_result['nor_sum_cpu_allocated'])


# plt.plot(df_result.index,df_result['sum_Mem'],label="presser",color='r')
plt.plot(df_result.index,df_result['sum_Mem'],label="PRESSER",color='tab:red')


plt.plot(dac_500G_pickle.index,dac_500G_pickle['sum_Mem'],label="DAC",color='tab:blue')

# plt.plot(np.,df_result['nor_sum_cpu_allocated'])

# plt.plot(np.arange(0, 300,1, dtype=int),df_result['nor_sum_cpu_allocated'])

# plt.ylim(100,500)

# legend
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 6}

#plt.legend(loc="upper right",prop=plt.rc('font', **font))
plt.legend(loc="upper left",prop=plt.rc('font', **font))

plt.legend(loc="upper left",prop=plt.rc('font', **font), labelspacing=0.1,
#            shadow=True,
#           fancybox=True,
#           facecolor='#C19A6B',
           framealpha=1,
          edgecolor='black')

# plt.legend(prop=plt.rc('font', **font),bbox_to_anchor=(0.8,0.61))

# grid
plt.grid(axis='y',color='black', linestyle='--', linewidth=1)


# plt.xticks(np.arange(0, 600, step=100))
plt.xlim(0,500)

plt.yticks(np.arange(100, 600, step=100))


# plt.title("TPCds-500GB - 6 workloads")
plt.xlabel("Time taken (seconds)",fontweight='bold',fontsize=9)
plt.ylabel("Memory (GB)",fontweight='bold',fontsize=8)



plt.tight_layout(pad=0)

# figure size
fig = plt.gcf()
fig.set_size_inches(6, 1)


# plt.tight_layout()

# plt.figure(figsize=(6, 1))

plt.savefig('./TPCds-500GB-memory-runtime.pdf', format='pdf', bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(4,18))
plt.figure(dpi=800)

df_result.plot(x="slave1time", y=["sum_CPU"],color={"sum_CPU": "black"})

# plt.show()

plt.savefig('example_cpu.png',dpi=300)

# %%
df_result['sum_CPU'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# memory 


df_result.plot(x="slave1time", y=["sum_Mem"],color={"sum_Mem": "black"})
plt.show()

# %%
plt.figure(figsize=(4,18))
plt.figure(dpi=800)

df_result.plot(x="slave1time", y=["sum_Mem"],color={"sum_Mem": "black"})

# plt.show()

plt.savefig('hos_mem.png',dpi=300)

# %%
df_result['sum_Mem'].describe()
actual_max_mem = df_result['sum_Mem'].max() - df_result['sum_Mem'].min()
actual_max_mem
# Out:
# 92.183

# %%
13*5.3
# Out:
# 68.89999999999999

# %%
df_result['sum_Mem'].describe()
# Out:
# count     98.000000
# mean      88.023561
# std       37.002229
# min       53.777000
# 25%       54.193750
# 50%       60.489500
# 75%      122.425000
# max      145.960000
# Name: sum_Mem, dtype: float64

# %%
import seaborn as sns
sns.set()

#sns.set_style("whitegrid")

#sns.set_style("white")

sns.set_style("ticks")


df_result.plot(x="slave1time", y=["slave1Mem", "slave2Mem", "slave3Mem","slave4Mem","slave5Mem","slave6Mem","sum_Mem"])
plt.show()

# %%
import sys
print(sys.executable)
# Out:
# /home/lemaker/PycharmProjects/chapter2_machine_learning/venv/bin/python3
